# %%
from gurobipy import *
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import stats
import time

# %% [markdown]
# # Punto 2

# %%
infty = math.inf

#Costo amortizado
C1, C2, C3 = 3.7,3.8,4
C = np.array([C1,C2,C3])
Q_EXTRA = 15

# suma de 
C_MAX = 8000 

#Costo operación diaria
Q1, Q2, Q3 = 2.7,2.6,2.5

#Costo importacion de energia


# DEMANDA ALTA MEDIA Y BAJA

DEMANDA_ALTA = 300
DEMANDA_MEDIA = 250
DEMANDA_BAJA = 200


# posibles xi
K = 1000

# posibles parametros de incertidumbre

capacidades_gen1 = stats.beta.rvs(8,2,size=K)
capacidades_gen2 = stats.beta.rvs(8,2,size=K)
capacidades_gen3 = stats.beta.rvs(8,2,size=K)

demandas_altas = stats.uniform.rvs(DEMANDA_ALTA, scale = DEMANDA_ALTA*0.2 ,size= K)
demandas_medias = stats.uniform.rvs(DEMANDA_MEDIA, scale = DEMANDA_MEDIA*0.2 ,size= K)
demandas_bajas = stats.uniform.rvs(DEMANDA_BAJA, scale = DEMANDA_BAJA*0.2 ,size= K)


#probabilidad de tomar alguna realización

prob = 1/K

# %%
plt.hist(capacidades_gen1,alpha=0.3, label='Generador 1')
plt.hist(capacidades_gen2,alpha=0.3,  label='Generador 2')
plt.hist(capacidades_gen3,alpha=0.3,  label='Generador 3')
plt.xlabel(r'$a_i$')
plt.ylabel('Veces')
plt.legend()

# %%
plt.hist(demandas_bajas,alpha=0.5, label='Demanda baja')
plt.hist(demandas_medias,alpha=0.5,  label='Demanda media')
plt.hist(demandas_altas,alpha=0.5,  label='Demanda alta')
plt.xlabel('Demanda')
plt.ylabel('Veces')
plt.legend()

# %% [markdown]
# # Punto 3

# %% [markdown]
# ## L-Shaped

# %%
#PASO 2 
#NO SE USA!!


def feasibility_cut(xvs):
    
    xv = xvs
    
    D = np.zeros(3)
    d = 0
    
    feasCUT = 0
    
    for realiz in range(K):
        capacidad_gen1 = capacidades_gen1[realiz]
        capacidad_gen2 = capacidades_gen2[realiz]
        capacidad_gen3 = capacidades_gen3[realiz]
        demanda_alta = demandas_altas[realiz]
        demanda_media = demandas_medias[realiz]
        demanda_baja = demandas_bajas[realiz]
    
        problema_feasibility = Model("feasibility")
        problema_feasibility.setParam('OutputFlag', 0)

        y = problema_feasibility.addMVar(shape=21, lb=0.0, vtype = GRB.CONTINUOUS, name='y')
        vmas = problema_feasibility.addMVar(shape=12, lb=0.0, vtype = GRB.CONTINUOUS, name='v+')
        vmenos = problema_feasibility.addMVar(shape=12, lb=0.0, vtype = GRB.CONTINUOUS, name='v-')

        W = np.zeros((12,21))
        for i in range(9):
            W[i,i]=1
            W[i,i+9]=1

        W[9:12, 0:3] = np.eye(3)
        W[9:12, 3:6] = np.eye(3)
        W[9:12, 6:9] = np.eye(3)
        W[9:12, 18:21] = np.eye(3)

        T = np.zeros((12,3))
        T[0:3,0] = -capacidad_gen1*np.ones(3)
        T[3:6,1] = -capacidad_gen2*np.ones(3)
        T[6:9,2] = -capacidad_gen3*np.ones(3)

        h = np.zeros(12)
        h[9:12]= [demanda_baja, demanda_media, demanda_alta]


        problema_feasibility.setObjective(vmas.sum()+vmenos.sum(), GRB.MINIMIZE)

        constr = problema_feasibility.addConstr(W@y + np.eye(12)@vmas + np.eye(12)@vmenos == h.T - T@xv.T, "restric" )

        problema_feasibility.optimize();

        if problema_feasibility.objVal>0:
            PI_k =constr.PI
            D = PI_k@T
            d= PI_k@h
            feasCUT =1
            break
    
    return  feasCUT, D, d, realiz

# %%
#PASO 3
def problema_esclavo(xvs):
    
    xv = xvs
    
    E = np.zeros(3)
    e = 0

    
    for realiz in range(K):
        capacidad_gen1 = capacidades_gen1[realiz]
        capacidad_gen2 = capacidades_gen2[realiz]
        capacidad_gen3 = capacidades_gen3[realiz]
        demanda_alta = demandas_altas[realiz]
        demanda_media = demandas_medias[realiz]
        demanda_baja = demandas_bajas[realiz]

        problema_esclavo = Model("esclavo")
        problema_esclavo.setParam('OutputFlag', 0)

        y = problema_esclavo.addMVar(shape=21, lb=0.0, vtype = GRB.CONTINUOUS, name='y')

        W = np.zeros((12,21))
        for i in range(9):
            W[i,i]=1
            W[i,i+9]=1

        W[9:12, 0:3] = np.eye(3)
        W[9:12, 3:6] = np.eye(3)
        W[9:12, 6:9] = np.eye(3)
        W[9:12, 18:21] = np.eye(3)

        T = np.zeros((12,3))
        T[0:3,0] = -capacidad_gen1*np.ones(3)
        T[3:6,1] = -capacidad_gen2*np.ones(3)
        T[6:9,2] = -capacidad_gen3*np.ones(3)

        h = np.zeros(12)
        h[9:12]= [demanda_baja, demanda_media, demanda_alta]


        problema_esclavo.setObjective(Q1*(y[0]+y[1]+y[2]) + Q2*(y[3]+y[4]+y[5]) + Q3*(y[6]+y[7]+y[8]) + Q_EXTRA*(y[18]+y[19]+y[20]), GRB.MINIMIZE)

        constr = problema_esclavo.addConstr(W@y + T@xv.T == h.T, "restric" )

        problema_esclavo.optimize();

        PI_k = constr.PI
        E += PI_k @ T
        e += PI_k @ h

    E = prob*E
    e = prob*e
    w = e-E@xv
    return E,e,w

# %%
#PASO 0
r,s,v = 0, 0, 0

solucion = 0
Es = []
es = []
thetaIncluir = 0

start_time = time.time()
while solucion==0:
    
    #PASO 1 PROBLEMA MAESTRO
    v+=1
    
    problema_maestro = Model("maestro")
    problema_maestro.setParam('OutputFlag', 0)
    x = problema_maestro.addMVar(shape = 3, lb=0.0, vtype = GRB.CONTINUOUS, name = 'x')
    s1 = problema_maestro.addMVar(shape= 1, lb=0.0, vtype = GRB.CONTINUOUS, name = 's1')

    
    if len(Es)==0:
        theta = -infty
        problema_maestro.setObjective(C@x, GRB.MINIMIZE)
    else:
        thetaIncluir = 1
        theta = problema_maestro.addMVar(shape= 1, vtype = GRB.CONTINUOUS, name = 'theta')
        problema_maestro.setObjective(C@x + theta, GRB.MINIMIZE)

    ##Ax=b
    constr = problema_maestro.addConstr(C@x + s1 == C_MAX, "costo_máximo" )
    
    for i in range(s):
        problema_maestro.addConstr(Es[i]@x + theta >= es[i]  ,"optimality_cut{}".format(i) )

    problema_maestro.optimize()

    todasVars = [var.x for var in problema_maestro.getVars()]
    
    xvs = np.array(todasVars[0:3])
    
    
    #feasibility_cut(xvs)
    
    
    ###PASO 3 PROBLEMA ESCLAVO
    
    E,e,w = problema_esclavo(xvs)

    
    print("iteración: ", v)
    
        
    if thetaIncluir==0:
        s+=1
        Es.append(E)
        es.append(e)
        continue
         
    elif theta.x+1e-6>=w:
        solucion=1
        print("La solución es: ", xvs)
        duraciontiempo = time.time() - start_time
        print("El programa demoró: ", duraciontiempo, " s")
        
    else:
        s+=1
        Es.append(E)
        es.append(e)
# Out:
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# iteración:  8
# iteración:  9
# iteración:  10
# iteración:  11
# iteración:  12
# iteración:  13
# iteración:  14
# iteración:  15
# iteración:  16
# iteración:  17
# iteración:  18
# iteración:  19
# iteración:  20
# iteración:  21
# iteración:  22
# iteración:  23
# iteración:  24
# iteración:  25
# iteración:  26
# iteración:  27
# iteración:  28
# iteración:  29
# iteración:  30
# iteración:  31
# iteración:  32
# iteración:  33
# iteración:  34
# iteración:  35
# iteración:  36
# iteración:  37
# iteración:  38
# iteración:  39
# iteración:  40
# iteración:  41
# iteración:  42
# iteración:  43
# iteración:  44
# iteración:  45
# La solución es:  [127.09336456 133.53198906 163.95232677]
# El programa demoró:  460.04187655448914  s

# %% [markdown]
# ## L-Shaped Multicut

# %%
#PASO 3
def problema_esclavo_multicut(xvs, thetas_prob, sks, Es, es):
    
    xv = xvs
    holds = 0
    
    
    for realiz in range(K):
        capacidad_gen1 = capacidades_gen1[realiz]
        capacidad_gen2 = capacidades_gen2[realiz]
        capacidad_gen3 = capacidades_gen3[realiz]
        demanda_alta = demandas_altas[realiz]
        demanda_media = demandas_medias[realiz]
        demanda_baja = demandas_bajas[realiz]
    
#     for capacidad_gen1 in capacidades_gen1:
#         for capacidad_gen2 in capacidades_gen2:
#             for capacidad_gen3 in capacidades_gen3:
#                 for demanda_alta in demandas_altas:
#                     for demanda_media in demandas_medias:
#                         for demanda_baja in demandas_bajas:
                            
                                
        problema_esclavoMulti = Model("multicut_esclavo")
        problema_esclavoMulti.setParam('OutputFlag', 0)

        y = problema_esclavoMulti.addMVar(shape=21, lb=0.0, vtype = GRB.CONTINUOUS, name='y')

        W = np.zeros((12,21))
        for i in range(9):
            W[i,i]=1
            W[i,i+9]=1

        W[9:12, 0:3] = np.eye(3)
        W[9:12, 3:6] = np.eye(3)
        W[9:12, 6:9] = np.eye(3)
        W[9:12, 18:21] = np.eye(3)

        T = np.zeros((12,3))
        T[0:3,0] = -capacidad_gen1*np.ones(3)
        T[3:6,1] = -capacidad_gen2*np.ones(3)
        T[6:9,2] = -capacidad_gen3*np.ones(3)

        h = np.zeros(12)
        h[9:12]= [demanda_baja, demanda_media, demanda_alta]


        problema_esclavoMulti.setObjective(Q1*(y[0]+y[1]+y[2]) + Q2*(y[3]+y[4]+y[5]) + Q3*(y[6]+y[7]+y[8]) + Q_EXTRA*(y[18]+y[19]+y[20]), GRB.MINIMIZE)

        constr = problema_esclavoMulti.addConstr(W@y + T@xv.T == h.T, "restric" )

        problema_esclavoMulti.optimize();

        PI_k = constr.PI

        if thetas_prob[realiz]+1e-6<prob*PI_k@(h - T@xv.T):
            Es[realiz].append(prob*PI_k@T)
            es[realiz].append(prob*PI_k@h)
            sks[realiz]+=1
            holds = 1
                                              
    return holds, Es, es, sks

# %%
#PASO 0
r,v = 0, 0
sks = np.zeros(K, dtype=int)

solucion = 0

Es = {el:[] for el in range(K)}
es = {el:[] for el in range(K)}

Ds = {el:[] for el in range(K)}
ds = {el:[] for el in range(K)}


thetaIncluir = 0


thetas_prob = np.zeros(K)

start_time = time.time()


while solucion==0:
    
    #PASO 1 PROBLEMA MAESTRO
    v+=1
    
    problema_maestro = Model("maestro")
    problema_maestro.setParam('OutputFlag', 0)
    x = problema_maestro.addMVar(shape = 3, lb=0.0, vtype = GRB.CONTINUOUS, name = 'x')
    s1 = problema_maestro.addMVar(shape= 1, lb=0.0, vtype = GRB.CONTINUOUS, name = 's1')

        
    theta_indx = []
    
    for key in list(Es.keys()):
        if len(Es[key])==0:
            thetas_prob[key] = -infty
        elif len(Es[key])!=0:
            theta_indx.append(key)
    
    if len(theta_indx)==0:
        problema_maestro.setObjective(C@x, GRB.MINIMIZE)
    else:
        thetas = problema_maestro.addMVar(shape = len(theta_indx), vtype = GRB.CONTINUOUS, name = 'thetas')
        problema_maestro.setObjective(C@x + thetas.sum(), GRB.MINIMIZE)
    
    
#     constTheta = np.sum(np.array([len(Es[key])  for key in list(Es.keys())]))
    
#     if constTheta==0:
#         thetas = -infty*np.ones(K)
#         problema_maestro.setObjective(C@x, GRB.MINIMIZE)
#     else:
#         thetaIncluir = 1
#         thetas = problema_maestro.addMVar(shape = K, vtype = GRB.CONTINUOUS, name = 'thetas')
#         problema_maestro.setObjective(C@x + thetas.sum(), GRB.MINIMIZE)

    ##Ax=b
    
    
    constr = problema_maestro.addConstr(C@x + s1 == C_MAX, "costo_máximo" )
    
    
    for count,j in enumerate(theta_indx):
        for i in range(sks[j]):
            problema_maestro.addConstr(Es[j][i]@x + thetas[count] >= es[j][i]  ,"optimality_cut{}{}".format(i,j) )
            
#     for j in range(K):
#         for i in range(len(Ds[j])):
#             print("INTRODUCE FEASIBILITY CUT")
#             problema_maestro.addConstr(Ds[j][i]@x >= ds[j][i], "feasibility_cut{}{}".format(i,j))

    problema_maestro.optimize()

    xvs = x.x
        
#     feasCUT, D, d, realiz = feasibility_cut(xvs)
#     if feasCUT==1:
#         Ds[realiz].append(D)
#         ds[realiz].append(d)
#         r+=1
#         continue
    
    for count, indx in enumerate(theta_indx):
        thetas_prob[indx] = thetas.x[count]
    
#     if thetaIncluir==0:
#         thetas_prob = thetas
#     elif thetaIncluir==1:
#         thetas_prob = thetas.x
    
    ###PASO 3 PROBLEMA ESCLAVO
    
    holds, Es, es, sks = problema_esclavo_multicut(xvs, thetas_prob, sks, Es, es)
    
    print("iteración: ", v)
    
    if holds==0:
        solucion=1
        print("La solución es: ", xvs)
        duraciontiempo = time.time() - start_time
        print("El programa demoró: ", duraciontiempo, " s")
# Out:
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [127.09336456 133.53198906 163.95232677]
# El programa demoró:  97.50122117996216  s

# %%
KSPLOT = [100, 300, 500,700, 1000]
Lclassic_time= [27.59734797477722, 101.54936838150024,  157.1003918647766,291.3554391860962, 433.6596882343292]
Lclassic_iter = [35, 42, 41,46, 50]
Lmulti_time = [6.108966588973999, 27.47972059249878, 33.368552684783936,67.00037860870361, 68.61579990386963]
Lmulti_iter = [6,7, 6,6,  6]

Sol={100:np.array([150.86523575, 140.46869699, 143.72934296]), 300:np.array([107.2121118 , 140.78156057 ,173.83912858 ] )    ,  500: np.array( [111.65680044, 163.99738382, 150.10143089] ) , 700: np.array([124.38312732, 128.21104386, 171.27352362]), 1000:np.array([131.72546326, 133.67334026, 160.12947004]) }


plt.plot(KSPLOT, Lclassic_time, marker = 'o' ,label = 'L-shaped')
plt.plot(KSPLOT, Lmulti_time, marker='o', label ='L-shaped Multicut')
plt.xlabel('Realizaciones K')
plt.ylabel("Tiempo [s]")
plt.legend()

# %%
plt.plot(KSPLOT, Lclassic_iter, marker = 'o' ,label = 'L-shaped')
plt.plot(KSPLOT, Lmulti_iter, marker='o', label ='L-shaped Multicut')
plt.xlabel('Realizaciones K')
plt.ylabel("Iteraciones")
plt.legend()

# %% [markdown]
# ### Comparación de iteraciones y tiempos de ambos métodos

# %% [markdown]
# # Punto 4

# %% [markdown]
# Para la parte a) usamos los mismos datos del punto 2 y para la parte b) se generan posteriormente:

# %%
Nsamples = 5000

capacidades_gen1_TLC = stats.beta.rvs(8,2,size=Nsamples)
capacidades_gen2_TLC = stats.beta.rvs(8,2,size=Nsamples)
capacidades_gen3_TLC = stats.beta.rvs(8,2,size=Nsamples)

demandas_altas_TLC = stats.uniform.rvs(DEMANDA_ALTA, scale = DEMANDA_ALTA*0.2 ,size= Nsamples)
demandas_medias_TLC = stats.uniform.rvs(DEMANDA_MEDIA, scale = DEMANDA_MEDIA*0.2 ,size= Nsamples)
demandas_bajas_TLC = stats.uniform.rvs(DEMANDA_BAJA, scale = DEMANDA_BAJA*0.2 ,size= Nsamples)


def funQ(xhat, capacidad_gen1, capacidad_gen2, capacidad_gen3, demanda_alta, demanda_media, demanda_baja) :
    problema_Q = Model("funQ")
    problema_Q.setParam('OutputFlag', 0)

    y = problema_Q.addMVar(shape=21, lb=0.0, vtype = GRB.CONTINUOUS, name='y')

    W = np.zeros((12,21))
    for i in range(9):
        W[i,i]=1
        W[i,i+9]=1

    W[9:12, 0:3] = np.eye(3)
    W[9:12, 3:6] = np.eye(3)
    W[9:12, 6:9] = np.eye(3)
    W[9:12, 18:21] = np.eye(3)

    T = np.zeros((12,3))
    T[0:3,0] = -capacidad_gen1*np.ones(3)
    T[3:6,1] = -capacidad_gen2*np.ones(3)
    T[6:9,2] = -capacidad_gen3*np.ones(3)

    h = np.zeros(12)
    h[9:12]= [demanda_baja, demanda_media, demanda_alta]


    problema_Q.setObjective(Q1*(y[0]+y[1]+y[2]) + Q2*(y[3]+y[4]+y[5]) + Q3*(y[6]+y[7]+y[8]) + Q_EXTRA*(y[18]+y[19]+y[20]), GRB.MINIMIZE)

    constr = problema_Q.addConstr(W@y + T@xhat.T == h.T, "restric" )

    problema_Q.optimize();
    return problema_Q.objVal

# %%
xhat = xvs
Dhat = 0

##CAMBIAR CAPACIDADES_GEN Y TODO PARA QUE HAYAN 15000 SAMPLES

for realiz in range(K):
    capacidad_gen1 = capacidades_gen1_TLC[realiz]
    capacidad_gen2 = capacidades_gen2_TLC[realiz]
    capacidad_gen3 = capacidades_gen3_TLC[realiz]
    demanda_alta = demandas_altas_TLC[realiz]
    demanda_media = demandas_medias_TLC[realiz]
    demanda_baja = demandas_bajas_TLC[realiz]
    Dhat += funQ(xhat, capacidad_gen1, capacidad_gen2, capacidad_gen3, demanda_alta, demanda_media, demanda_baja)

Dhat = Dhat/Nsamples

sigma2 = 0
for realiz in range(K):
    capacidad_gen1 = capacidades_gen1_TLC[realiz]
    capacidad_gen2 = capacidades_gen2_TLC[realiz]
    capacidad_gen3 = capacidades_gen3_TLC[realiz]
    demanda_alta = demandas_altas_TLC[realiz]
    demanda_media = demandas_medias_TLC[realiz]
    demanda_baja = demandas_bajas_TLC[realiz]
    sigma2 += (funQ(xhat, capacidad_gen1, capacidad_gen2, capacidad_gen3, demanda_alta, demanda_media, demanda_baja) - Dhat )**2

sigma2 = sigma2/(Nsamples-1)

# %% [markdown]
# Para $\alpha = 0.01$ tenemos que $z_{\alpha/2} = 2.5758$. La cota superior es:

# %%
zalpha  =2.5758
cotaSuperior = C@xhat + Dhat + zalpha*sigma2/np.sqrt(Nsamples)
cotaSuperior
# Out:
# 26017.097384906643

# %%
sigma2
# Out:
# 657084.5165967195

# %%
print("dhat: ", Dhat, "\nsigma2: ", sigma2)
# Out:
# dhat:  447.797756693144
# sigma2:  657084.5165967195

# %%
Msamples = 50

capacidades_gen1_M = []
capacidades_gen2_M = []
capacidades_gen3_M = []
demandas_altas_M = []
demandas_medias_M = []
demandas_bajas_M = []

for m in range(Msamples):
    capacidades_gen1_M.append(stats.beta.rvs(8,2,size=K))
    capacidades_gen2_M.append(stats.beta.rvs(8,2,size=K))
    capacidades_gen3_M.append(stats.beta.rvs(8,2,size=K))
    demandas_altas_M.append(stats.uniform.rvs(DEMANDA_ALTA, scale = DEMANDA_ALTA*0.2 ,size= K))
    demandas_medias_M.append( stats.uniform.rvs(DEMANDA_MEDIA, scale = DEMANDA_MEDIA*0.2 ,size= K))
    demandas_bajas_M.append(stats.uniform.rvs(DEMANDA_BAJA, scale = DEMANDA_BAJA*0.2 ,size= K))

def problema_esclavoM(xvs,capacidades_gen1In, capacidades_gen2In, capacidades_gen3In,demandas_altasIn, demandas_mediasIn, demandas_bajasIn, thetas_prob, sks, Es, es):
    
    xv = xvs
    holds = 0

    for realiz in range(K):
        capacidad_gen1 = capacidades_gen1In[realiz]
        capacidad_gen2 = capacidades_gen2In[realiz]
        capacidad_gen3 = capacidades_gen3In[realiz]
        demanda_alta = demandas_altasIn[realiz]
        demanda_media = demandas_mediasIn[realiz]
        demanda_baja = demandas_bajasIn[realiz]

        problema_esclavoMulti = Model("multicut_esclavo")
        problema_esclavoMulti.setParam('OutputFlag', 0)

        y = problema_esclavoMulti.addMVar(shape=21, lb=0.0, vtype = GRB.CONTINUOUS, name='y')

        W = np.zeros((12,21))
        for i in range(9):
            W[i,i]=1
            W[i,i+9]=1

        W[9:12, 0:3] = np.eye(3)
        W[9:12, 3:6] = np.eye(3)
        W[9:12, 6:9] = np.eye(3)
        W[9:12, 18:21] = np.eye(3)

        T = np.zeros((12,3))
        T[0:3,0] = -capacidad_gen1*np.ones(3)
        T[3:6,1] = -capacidad_gen2*np.ones(3)
        T[6:9,2] = -capacidad_gen3*np.ones(3)

        h = np.zeros(12)
        h[9:12]= [demanda_baja, demanda_media, demanda_alta]


        problema_esclavoMulti.setObjective(Q1*(y[0]+y[1]+y[2]) + Q2*(y[3]+y[4]+y[5]) + Q3*(y[6]+y[7]+y[8]) + Q_EXTRA*(y[18]+y[19]+y[20]), GRB.MINIMIZE)

        constr = problema_esclavoMulti.addConstr(W@y + T@xv.T == h.T, "restric" )

        problema_esclavoMulti.optimize();

        PI_k = constr.PI

        if thetas_prob[realiz]+1e-6<prob*PI_k@(h - T@xv.T):
            Es[realiz].append(prob*PI_k@T)
            es[realiz].append(prob*PI_k@h)
            sks[realiz]+=1
            holds = 1
                                              
    return holds, Es, es, sks

# %%
fs = np.zeros(Msamples)
for m in range(Msamples):
    
    capacidades_gen1In = capacidades_gen1_M[m]
    capacidades_gen2In = capacidades_gen2_M[m]
    capacidades_gen3In = capacidades_gen3_M[m]
    demandas_altasIn = demandas_altas_M[m]
    demandas_mediasIn = demandas_medias_M[m]
    demandas_bajasIn = demandas_bajas_M[m]
    
    r,v = 0, 0
    sks = np.zeros(K, dtype=int)

    solucion = 0

    Es = {el:[] for el in range(K)}
    es = {el:[] for el in range(K)}

    Ds = {el:[] for el in range(K)}
    ds = {el:[] for el in range(K)}


    thetaIncluir = 0


    thetas_prob = np.zeros(K)

    start_time = time.time()


    while solucion==0:

        #PASO 1 PROBLEMA MAESTRO
        v+=1

        problema_maestro = Model("maestro")
        problema_maestro.setParam('OutputFlag', 0)
        x = problema_maestro.addMVar(shape = 3, lb=0.0, vtype = GRB.CONTINUOUS, name = 'x')
        s1 = problema_maestro.addMVar(shape= 1, lb=0.0, vtype = GRB.CONTINUOUS, name = 's1')


        theta_indx = []

        for key in list(Es.keys()):
            if len(Es[key])==0:
                thetas_prob[key] = -infty
            elif len(Es[key])!=0:
                theta_indx.append(key)

        if len(theta_indx)==0:
            problema_maestro.setObjective(C@x, GRB.MINIMIZE)
        else:
            thetas = problema_maestro.addMVar(shape = len(theta_indx), vtype = GRB.CONTINUOUS, name = 'thetas')
            problema_maestro.setObjective(C@x + thetas.sum(), GRB.MINIMIZE)




        constr = problema_maestro.addConstr(C@x + s1 == C_MAX, "costo_máximo" )


        for count,j in enumerate(theta_indx):
            for i in range(sks[j]):
                problema_maestro.addConstr(Es[j][i]@x + thetas[count] >= es[j][i]  ,"optimality_cut{}{}".format(i,j) )

        problema_maestro.optimize()

        xvs = x.x

        for count, indx in enumerate(theta_indx):
            thetas_prob[indx] = thetas.x[count]


        holds, Es, es, sks = problema_esclavoM(xvs,capacidades_gen1In, capacidades_gen2In, capacidades_gen3In,demandas_altasIn, demandas_mediasIn, demandas_bajasIn, thetas_prob, sks, Es, es)

        print("iteración: ", v)
        
        if holds==0:
            solucion=1
            print("La solución es: ", xvs)
            duraciontiempo = time.time() - start_time
            print("El programa demoró: ", duraciontiempo, " s")

    fs[m] = problema_maestro.objVal
# Out:
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [124.5432759  135.33393204 167.51083528]
# El programa demoró:  108.09631180763245  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [109.4450959  154.86597555 158.93198882]
# El programa demoró:  98.17865252494812  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [144.00398863 123.60655545 157.11341152]
# El programa demoró:  78.97978401184082  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [ 96.8685993  142.93835317 185.74408716]
# El programa demoró:  89.8335657119751  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [135.85986437 131.72213705 161.10247564]
# El programa demoró:  96.0076072216034  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [125.15474872 157.22416924 142.0720208 ]
# El programa demoró:  84.43500971794128  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [125.17260609 139.0481872  158.76788346]
# El programa demoró:  97.8795325756073  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [127.16668839 142.56393877 151.89176326]
# El programa demoró:  98.97325277328491  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [108.25101183 149.17813742 168.8371336 ]
# El programa demoró:  92.10733413696289  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [115.54242281 136.58083756 173.11707103]
# El programa demoró:  108.3852789402008  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [123.13875395 148.43543782 153.42447477]
# El programa demoró:  100.62673020362854  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [108.88103966 144.60228112 169.71384435]
# El programa demoró:  90.54005599021912  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [135.79045761 124.25799388 168.39305929]
# El programa demoró:  109.53308773040771  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [126.01815422 145.89540389 153.48503899]
# El programa demoró:  84.83614683151245  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [131.20859012 148.1921617  144.24231873]
# El programa demoró:  109.31977105140686  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [136.2943786  126.80202498 162.48682325]
# El programa demoró:  88.83971905708313  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [117.87316168 142.25189052 166.28379438]
# El programa demoró:  88.6576738357544  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [126.47073515 125.92103609 172.7913974 ]
# El programa demoró:  100.40696978569031  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [128.55402758 144.2471501  152.05299514]
# El programa demoró:  100.88905620574951  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [121.653738   139.38577885 165.76523503]
# El programa demoró:  72.74500107765198  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [119.16473675 152.74083418 150.64300765]
# El programa demoró:  75.46901631355286  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [102.09864462 155.31708513 165.76099755]
# El programa demoró:  89.23625135421753  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [120.86059116 132.75007223 171.99907532]
# El programa demoró:  93.32347702980042  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [128.62000562 145.17926326 148.83906341]
# El programa demoró:  80.505619764328  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [116.92659744 148.17700572 160.74344503]
# El programa demoró:  81.82893967628479  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [118.88583974 141.58010825 164.60812194]
# El programa demoró:  93.40511178970337  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [127.12841204 138.16083941 161.16429919]
# El programa demoró:  67.86362290382385  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [ 99.26617525 148.66074699 175.91967635]
# El programa demoró:  80.64453506469727  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [120.19932265 158.64911639 146.89516315]
# El programa demoró:  61.6894953250885  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [123.94110603 136.25704039 164.02643234]
# El programa demoró:  58.65444016456604  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [129.42882205 123.15547163 170.17140777]
# El programa demoró:  70.09398126602173  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [118.61384133 138.26504304 167.09878982]
# El programa demoró:  59.45213079452515  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [130.89291236 121.43327525 173.08558372]
# El programa demoró:  127.69892072677612  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [112.80691045 145.49361903 167.42300578]
# El programa demoró:  137.58459663391113  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [126.48835483 158.43529473 141.2366094 ]
# El programa demoró:  92.67997002601624  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [136.66181152 143.61532587 144.92514677]
# El programa demoró:  61.82879567146301  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [114.37316848 155.29047327 154.42574112]
# El programa demoró:  68.77498960494995  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [121.50823191 159.89109927 142.51707901]
# El programa demoró:  64.5736289024353  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [122.37906606 163.42969821 139.24397053]
# El programa demoró:  76.47129154205322  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [124.75476349 140.67221288 158.95278251]
# El programa demoró:  64.10579895973206  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [133.50036748 132.5254787  159.58407538]
# El programa demoró:  92.87750005722046  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [127.40045414 145.59053676 151.0363975 ]
# El programa demoró:  75.10266184806824  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [114.08672793 134.01764682 174.8386216 ]
# El programa demoró:  69.55491900444031  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [129.14790834 136.46739658 157.98864539]
# El programa demoró:  59.54137396812439  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [128.18235967 143.62573837 151.73230023]
# El programa demoró:  66.61413073539734  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [123.13654695 140.87948101 159.11353898]
# El programa demoró:  65.89080691337585  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# La solución es:  [126.66218642 143.76743417 155.02359007]
# El programa demoró:  58.423158407211304  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [ 98.28610377 155.99196062 169.81240058]
# El programa demoró:  66.1667046546936  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [129.70052397 163.16792369 132.77239986]
# El programa demoró:  66.74655151367188  s
# iteración:  1
# iteración:  2
# iteración:  3
# iteración:  4
# iteración:  5
# iteración:  6
# iteración:  7
# La solución es:  [120.76309207 144.16953535 161.39801977]
# El programa demoró:  70.06996703147888  s

# %%
fs_media = np.sum(fs)/Msamples
fs_var = np.sum([(fs[m]-fs_media)**2 for m in range(Msamples)] )/(Msamples-1)

cotaInferior = fs_media - zalpha*fs_var/np.sqrt(Msamples)

# %%
brecha = cotaSuperior - cotaInferior
brecha
# Out:
# 22169.649576533775

# %%
print("la brecha es del ", 100*brecha/fs_media, "%")
# Out:
# la brecha es del  571.652880948647 %

# %%
fs_var
# Out:
# 84.3282778513989

# %%
cotaSuperior
# Out:
# 26017.097384906643

# %%
cotaInferior
# Out:
# 3847.4478083728673

# %% [markdown]
# ## de aquí para abajo no se usó

# %%
Msamples = 100

capacidades_gen1_M = []
capacidades_gen2_M = []
capacidades_gen3_M = []
demandas_altas_M = []
demandas_medias_M = []
demandas_bajas_M = []

for m in range(Msamples):
    capacidades_gen1_M.append(stats.beta.rvs(8,2,size=K))
    capacidades_gen2_M.append(stats.beta.rvs(8,2,size=K))
    capacidades_gen3_M.append(stats.beta.rvs(8,2,size=K))
    demandas_altas_M.append(stats.uniform.rvs(DEMANDA_ALTA, scale = DEMANDA_ALTA*0.2 ,size= K))
    demandas_medias_M.append( stats.uniform.rvs(DEMANDA_MEDIA, scale = DEMANDA_MEDIA*0.2 ,size= K))
    demandas_bajas_M.append(stats.uniform.rvs(DEMANDA_BAJA, scale = DEMANDA_BAJA*0.2 ,size= K))

def problema_esclavoM(xvs,capacidades_gen1In, capacidades_gen2In, capacidades_gen3In,demandas_altasIn, demandas_mediasIn, demandas_bajasIn):
    
    xv = xvs
    
    E = np.zeros(3)
    e = 0

    for realiz in range(K):
        capacidad_gen1 = capacidades_gen1In[realiz]
        capacidad_gen2 = capacidades_gen2In[realiz]
        capacidad_gen3 = capacidades_gen3In[realiz]
        demanda_alta = demandas_altasIn[realiz]
        demanda_media = demandas_mediasIn[realiz]
        demanda_baja = demandas_bajasIn[realiz]

        problema_esclavo = Model("esclavo")
        problema_esclavo.setParam('OutputFlag', 0)

        y = problema_esclavo.addMVar(shape=21, lb=0.0, vtype = GRB.CONTINUOUS, name='y')

        W = np.zeros((12,21))
        for i in range(9):
            W[i,i]=1
            W[i,i+9]=1

        W[9:12, 0:3] = np.eye(3)
        W[9:12, 3:6] = np.eye(3)
        W[9:12, 6:9] = np.eye(3)
        W[9:12, 18:21] = np.eye(3)

        T = np.zeros((12,3))
        T[0:3,0] = -capacidad_gen1*np.ones(3)
        T[3:6,1] = -capacidad_gen2*np.ones(3)
        T[6:9,2] = -capacidad_gen3*np.ones(3)

        h = np.zeros(12)
        h[9:12]= [demanda_baja, demanda_media, demanda_alta]


        problema_esclavo.setObjective(Q1*(y[0]+y[1]+y[2]) + Q2*(y[3]+y[4]+y[5]) + Q3*(y[6]+y[7]+y[8]) + Q_EXTRA*(y[18]+y[19]+y[20]), GRB.MINIMIZE)

        constr = problema_esclavo.addConstr(W@y + T@xv.T == h.T, "restric" )

        problema_esclavo.optimize();

        PI_k = constr.PI
        E += PI_k @ T
        e += PI_k @ h

    E = prob*E
    e = prob*e
    w = e-E@xv
    return E,e,w

# %%
fs = np.zeros(Msamples)
for m in range(Msamples):
    
    capacidades_gen1In = capacidades_gen1_M[m]
    capacidades_gen2In = capacidades_gen2_M[m]
    capacidades_gen3In = capacidades_gen3_M[m]
    demandas_altasIn = demandas_altas_M[m]
    demandas_mediasIn = demandas_medias_M[m]
    demandas_bajasIn = demandas_bajas_M[m]
    
    r,s,v = 0, 0, 0

    solucion = 0
    Es = []
    es = []
    thetaIncluir = 0
    while solucion==0:

        #PASO 1 PROBLEMA MAESTRO
        v+=1

        problema_maestro = Model("maestro")
        problema_maestro.setParam('OutputFlag', 0)
        x = problema_maestro.addMVar(shape = 3, lb=0.0, vtype = GRB.CONTINUOUS, name = 'x')
        s1 = problema_maestro.addMVar(shape= 1, lb=0.0, vtype = GRB.CONTINUOUS, name = 's1')


        if len(Es)==0:
            theta = -infty
            problema_maestro.setObjective(C@x, GRB.MINIMIZE)
        else:
            thetaIncluir = 1
            theta = problema_maestro.addMVar(shape= 1, vtype = GRB.CONTINUOUS, name = 'theta')
            problema_maestro.setObjective(C@x + theta, GRB.MINIMIZE)

        ##Ax=b
        constr = problema_maestro.addConstr(C@x + s1 == C_MAX, "costo_máximo" )

        for i in range(s):
            problema_maestro.addConstr(Es[i]@x + theta >= es[i]  ,"optimality_cut{}".format(i) )

        problema_maestro.optimize()

        todasVars = [var.x for var in problema_maestro.getVars()]

        xvs = np.array(todasVars[0:3])


        #feasibility_cut(xvs)


        ###PASO 3 PROBLEMA ESCLAVO
        

        E,e,w = problema_esclavoM(xvs,capacidades_gen1In, capacidades_gen2In, capacidades_gen3In,demandas_altasIn, demandas_mediasIn, demandas_bajasIn)


        print("iteración: ", v)


        if thetaIncluir==0:
            s+=1
            Es.append(E)
            es.append(e)
            continue

        elif theta.x+1e-6>=w:
            solucion=1

        else:
            s+=1
            Es.append(E)
            es.append(e)
    
    fs[m] = problema_maestro.objVal

# %%
fs_media = np.sum(fs)/Msamples
fs_var = np.sum([(fs[m]-fs_media)**2 for m in range(Msamples)] )/(Msamples-1)

cotaInferior = fs_media - zalpha*fs_var/np.sqrt(Msamples)

# %%
brecha = cotaSuperior - cotaInferior
brecha

# %%
cotaInferior

# %%
fs_media

# %%
fs_var
